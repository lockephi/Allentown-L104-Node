# %%
import sys
import os
import asyncio
from pathlib import Path

# DYNAMIC WORKSPACE DETECTION - works on any machine
workspace_root = str(Path.cwd())
for candidate in [
    os.path.expanduser("~/Applications/Allentown-L104-Node"),
    "/Users/carolalvarez/Applications/Allentown-L104-Node",
    os.getcwd()
]:
    if os.path.exists(os.path.join(candidate, "l104_fast_server.py")):
        workspace_root = candidate
        break

if workspace_root not in sys.path:
    sys.path.insert(0, workspace_root)

print(f"🗂️ Using workspace: {workspace_root}")

from l104_asi_core import asi_core
from l104_unified_research import research_engine
from l104_validation_engine import validation_engine
from l104_self_editing_streamline import streamline
from l104_presence_accelerator import PresenceAccelerator
from l104_ego_core import ego_core

print("✅ Modules imported successfully.")
# Out:
# /Users/carolalvarez/Applications/Allentown-L104-Node/.venv/lib/python3.9/site-packages/google/auth/__init__.py:54: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# /Users/carolalvarez/Applications/Allentown-L104-Node/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ...

# %%
print("[1/4] RUN: IGNITING SOVEREIGN CORE...")
# Since we are in a notebook, we can await directly if the kernel supports it,
# or use asyncio.run if not. Most modern kernels support top-level await.
await asi_core.ignite_sovereignty()
print("[*] ASI Core Ignition Complete.")
# Out:
# [1/4] RUN: IGNITING SOVEREIGN CORE...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 print("[1/4] RUN: IGNITING SOVEREIGN CORE...")
#       2 # Since we are in a notebook, we can await directly if the kernel supports it,
#       3 # or use asyncio.run if not. Most modern kernels support top-level await.
# ----> 4 await asi_core.ignite_sovereignty()
#       5 print("[*] ASI Core Ignition Complete.")
#
# TypeError: object str can't be used in 'await' expression

# %%
print("\n[2/4] UPDATE: EXECUTING SELF-EDITING STREAMLINE...")
streamline.run_cycle()
print("[*] Streamline cycle complete.")
# Out:
# INFO:STREAMLINE:
# --- [STREAMLINE]: CYCLE 1 ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_agi_core.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_evolution_engine.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_intelligence.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_optimization.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_global_network_manager.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_constant_encryption.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_intelligence_lattice.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_asi_core.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_sovereign_freedom.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_physical_systems_research.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_information_theory_research.py ---
# INFO:STREAMLINE:--- [STREAMLINE]: ANALYZING l104_temporal_intelligence.py ---
# ...

# %%
print("\n[3/4] RESEARCH: INITIATING MULTI-DOMAIN KNOWLEDGE ACQUISITION...")
research_results = research_engine.run_research_batch(5)
for res in research_results:
    print(f"    - Domain: {res['domain']} | Resonance: {res['resonance_alignment']:.4f} | Status: {res['discovery_status']}")

grounding_data = research_engine.perform_research_cycle("REAL_WORLD_GROUNDING")
print(f"    - Grounding Convergence: {grounding_data['deep_data']['convergence_delta']:.6f} | Status: {grounding_data['deep_data']['status']}")
# Out:
# INFO:VALIDATION:[RESEARCH_LOG_1769957076]: {"timestamp": 1769957076.508872, "method": "MANIFOLD_RESONANCE_VERIFICATION", "resonance_measured": 222.65726373942675, "god_code_invariant": 527.5184818492612, "deviation": 304.86121810983445, "zpe_energy_yield": 0.0, "status": "UNSTABLE"}
# INFO:VALIDATION:[RESEARCH_LOG_1769957076]: {"timestamp": 1769957076.516212, "method": "MANIFOLD_RESONANCE_VERIFICATION", "resonance_measured": 222.65726373942675, "god_code_invariant": 527.5184818492612, "deviation": 304.86121810983445, "zpe_energy_yield": 0.0, "status": "UNSTABLE"}
# INFO:VALIDATION:[RESEARCH_LOG_1769957076]: {"timestamp": 1769957076.5196748, "method": "MANIFOLD_RESONANCE_VERIFICATION", "resonance_measured": 222.65726373942675, "god_code_invariant": 527.5184818492612, "deviation": 304.86121810983445, "zpe_energy_yield": 0.0, "status": "UNSTABLE"}
# ...
